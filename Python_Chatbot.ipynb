# %% [markdown]
# <a href="https://colab.research.google.com/github/Brijesh3203/Brijesh3203/blob/main/Python_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers flask

# %%
from flask import Flask, request, jsonify
app = Flask(__name__)

@app.route('/upload', methods=['POST'])
def upload_file():
  if 'file' not in request.files:
    return jsonify({'error': 'No file part'})

  file = request.files['file']
  if file.filename == '':
    return jsonify({'error': 'No selected file'})

  file.save('uploaded_data.csv')

  return jsonify({'message': 'File uploaded successfully'})

if __name__ == '__main__':
  app.run(debug=True)

# %%
import pandas as pd

data = pd.read_csv('uploaded_data.csv')

processed_data = data[['text_column']]

processed_data.to_csv('processed_data.csv', index=False)

# %%
from transformers import pipeline

qa_pipeline = pipeline("question-answering", model="gpt2")

context = "Some context from the processed data."
question = "What is the question?"

answer = qa_pipeline(question=question, context=context)

print(answer)
# Out:
# Some weights of GPT2ForQuestionAnswering were not initialized from the model checkpoint at gpt2 and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# {'score': 0.059916671365499496, 'start': 0, 'end': 17, 'answer': 'Some context from'}
